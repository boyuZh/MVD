# %% [markdown]
# # Get the single task results

# %%
import json

def extract_json_structure(path):
    with open(path, "r") as file:
        content = file.read()

    lan = path.split("/")[-1].split("_")[2]
    start_index = content.find(f"{{'{lan}_accuracy':")
    # Find the start of the JSON-like structure
    # start_index = content.find(start_token)
    if start_index == -1:
        return None

    # Initialize counters for open and close curly braces
    open_braces = 0
    close_braces = 0

    # Iterate over the content to find the end of the JSON-like structure
    for i in range(start_index, len(content)):
        if content[i] == '{':
            open_braces += 1
        elif content[i] == '}':
            close_braces += 1
        if open_braces == close_braces and open_braces > 0:
            end_index = i
            json_str = content[start_index:end_index+1]
            # print(json_str)
            # Convert 'array(...)' to Python list format
            json_str = json_str.replace("array(", "")
            json_str = json_str.replace(")", "")
            parsed_data = eval(json_str)
            parsed_data['lan'] = lan
            parsed_data[f'{lan}_recall'] = parsed_data[f'{lan}_recall'][1]
            parsed_data[f'{lan}_precision'] = parsed_data[f'{lan}_precision'][1]
            parsed_data[f'{lan}_f1'] = parsed_data[f'{lan}_f1'][1]
            parsed_data.pop(f"{lan}_cm", None)
            return parsed_data

    print(f"Error: JSON-like structure not found in file {path}")
    return None

# %%
extract_json_structure("_logs_linevul/bigvul_results_Python_seed8432.out")
# Out:
# {'Python_accuracy': 0.9843962008141113,
#  'Python_ap': 0.9024974554362696,
#  'Python_recall': 0.81730769,
#  'Python_precision': 0.95505618,
#  'Python_f1': 0.88082902,
#  'Python_threshold': 0.9976,
#  'Python_mcc': 0.8755650561713234,
#  'lan': 'Python'}

# %%
# list all files end with .out
import os

# List all files in the provided directory that end with .out
def list_files_with_numbers(directory, numbers, strings):
    # Filter files whose names contain one of the specified numbers
    # List to store the matching files
    matching_files = []

    # Traverse the directory
    for dirpath, dirnames, filenames in os.walk(directory):
        for filename in filenames:
            # Check if the file ends with .out
            if filename.endswith('.out'):
                # Check if any of the numbers is in the filename
                if any(str(num) in filename for num in numbers):
                    # Check if any of the strings is in the filename
                    if any(s in filename for s in strings):
                        matching_files.append(os.path.join(dirpath, filename))

    return matching_files

# Directory path (replace with your target directory)
directory = '_logs_linevul//'

# List of numbers
numbers = [43, 6916, 25569, 8408, 72844, 8432, 9406, 6088, 25888, 76954]

# Strings to be present in the filename
languages = ["Python", "TypeScript", "Java", "CS", "CCPP", "JavaScript"]

# Get the list of matching files
matching_files = list_files_with_numbers(directory, numbers, languages)

# %%
json_list = [extract_json_structure(path) for path in matching_files]

# Remove None values
filtered_lst = [x for x in json_list if x is not None]

# %%
grouped_data = {}
averaged_data = {}
for item in filtered_lst:
    lan = item['lan']
    if lan not in grouped_data:
        grouped_data[lan] = []
    grouped_data[lan].append(item)

for lan, items in grouped_data.items():
    avg_item = {'lan': lan}
    metric_count = len(items)
    for item in items:
        for key, value in item.items():
            if key != 'lan' and isinstance(value, (int, float)):
                prefix = f"{lan}_"
                if key.startswith(prefix):
                    metric_key = key[len(prefix):]
                    avg_item[metric_key] = avg_item.get(metric_key, 0) + value
    for key, value in avg_item.items():
        if key != 'lan':
            avg_item[key] = value / metric_count
            avg_item[key] = round(avg_item[key], 4)
    averaged_data[lan] = avg_item

# %%
averaged_data
# Out:
# {'CS': {'lan': 'CS',
#   'accuracy': 0.8792,
#   'ap': 0.7627,
#   'recall': 0.5845,
#   'precision': 0.7685,
#   'f1': 0.6582,
#   'threshold': 0.2969,
#   'mcc': 0.599},
#  'TypeScript': {'lan': 'TypeScript',
#   'accuracy': 0.8963,
#   'ap': 0.3226,
#   'recall': 0.2141,
#   'precision': 0.3477,
#   'f1': 0.238,
#   'threshold': 0.093,
#   'mcc': 0.2071},
#  'Python': {'lan': 'Python',
#   'accuracy': 0.9858,
#   'ap': 0.8824,
#   'recall': 0.8101,
#   'precision': 0.9669,
#   'f1': 0.881,
#   'threshold': 0.8964,
#   'mcc': 0.8777},
#  'Java': {'lan': 'Java',
#   'accuracy': 0.908,
#   'ap': 0.3624,
#   'recall': 0.2688,
#   'precision': 0.3112,
#   'f1': 0.2869,
#   'threshold': 0.0566,
#   'mcc': 0.2398},
#  'CCPP': {'lan': 'CCPP',
#   'accuracy': 0.9519,
#   'ap': 0.2515,
#   'recall': 0.0773,
#   'precision': 0.6988,
#   'f1': 0.1366,
#   'threshold': 0.1258,
#   'mcc': 0.2165},
#  'JavaScript': {'lan': 'JavaScript',
#   'accuracy': 0.9139,
#   'ap': 0.5944,
#   'recall': 0.4752,
#   'precision': 0.5676,
#   'f1': 0.5152,
#   'threshold': 0.2167,
#   'mcc': 0.4719}}

# %% [markdown]
# ## Read the MC results

# %%
def extract_mc_json_structure(path, languages):
    with open(path, "r") as file:
        content = file.read()
        content = content.strip()
    
    if "11" not in content[:8]:
        print("Obsolete file", path)
        return None
    
    phase = "_".join(path.split("/")[-1].split("_")[2:-1])

    parsed_list = []

    for lan in languages:
        start_index = content.find(f"{{'{lan}_accuracy':")
        # Find the start of the JSON-like structure
        # start_index = content.find(start_token)
        if start_index == -1:
            continue

        # Initialize counters for open and close curly braces
        open_braces = 0
        close_braces = 0

        # Iterate over the content to find the end of the JSON-like structure
        for i in range(start_index, len(content)):
            if content[i] == '{':
                open_braces += 1
            elif content[i] == '}':
                close_braces += 1
            if open_braces == close_braces and open_braces > 0:
                end_index = i
                json_str = content[start_index:end_index+1]
                # print(json_str)
                # Convert 'array(...)' to Python list format
                json_str = json_str.replace("array(", "")
                json_str = json_str.replace(")", "")
                try:
                    parsed_data = eval(json_str)
                    parsed_data['lan'] = lan
                    parsed_data['phase'] = phase
                    parsed_data[f'{lan}_recall'] = parsed_data[f'{lan}_recall'][1]
                    parsed_data[f'{lan}_precision'] = parsed_data[f'{lan}_precision'][1]
                    parsed_data[f'{lan}_f1'] = parsed_data[f'{lan}_f1'][1]
                    parsed_data.pop(f"{lan}_cm", None)
                    parsed_list.append(parsed_data)
                    break
                except SyntaxError:
                    print(json_str)
                    return None

    if len(parsed_list) == 0:
        print(f"Error: JSON-like structure not found in file {path}")
        return None
    
    assert len(parsed_list) == len(languages), f"file path: {path}"
    return parsed_list

# %%
# Get the list of matching files
strings = ["mc"]
mc_matching_files = list_files_with_numbers(directory, numbers, strings)

# %%
mc_json_list = [extract_mc_json_structure(path, languages) for path in mc_matching_files]

# Remove None values
mc_filtered_lst = [x for x in mc_json_list if x is not None]

# %%
{item[0]['phase'] for item in mc_filtered_lst}
# Out:
# {'mc', 'mc_adj', 'mc_bin', 'mc_focal', 'mc_focal_adj', 'mc_freeze'}

# %%
mc_filtered_lst
# Out:
# [[{'Python_accuracy': 0.9506944444444444,
#    'Python_ap': 0.5134560405325834,
#    'Python_recall': 0.1954023,
#    'Python_precision': 0.94444444,
#    'Python_f1': 0.32380952,
#    'Python_threshold': 0.315,
#    'Python_mcc': 0.4174517955620673,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.9024390243902439,
#    'TypeScript_ap': 0.14691499656413354,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.0358,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.9376299376299376,
#    'Java_ap': 0.1383632465788265,
#    'Java_recall': 0.02352941,
#    'Java_precision': 0.22222222,
#    'Java_f1': 0.04255319,
#    'Java_threshold': 0.1001,
#    'Java_mcc': 0.05495225141052885,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.8282828282828283,
#    'CS_ap': 0.26965827780086327,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0234,
#    'CS_mcc': 0.0,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.9497170363624536,
#    'CCPP_ap': 0.1334721338111237,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.0621,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.9017948717948718,
#    'JavaScript_ap': 0.22681279837195578,
#    'JavaScript_recall': 0.0,
#    'JavaScript_precision': 0.0,
#    'JavaScript_f1': 0.0,
#    'JavaScript_threshold': 0.0637,
#    'JavaScript_mcc': 0.0,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.9838492597577388,
#    'Python_ap': 0.8800937439216836,
#    'Python_recall': 0.77227723,
#    'Python_precision': 0.98734177,
#    'Python_f1': 0.86666667,
#    'Python_threshold': 0.8768,
#    'Python_mcc': 0.8655496502739786,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.936,
#    'TypeScript_ap': 0.29275525211990905,
#    'TypeScript_recall': 0.15789474,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.27272727,
#    'TypeScript_threshold': 0.2291,
#    'TypeScript_mcc': 0.3842743000701953,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.9498257839721255,
#    'Java_ap': 0.42824837615159556,
#    'Java_recall': 0.1627907,
#    'Java_precision': 1.0,
#    'Java_f1': 0.28,
#    'Java_threshold': 0.3382,
#    'Java_mcc': 0.39311872273375853,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8495145631067961,
#    'CS_ap': 0.7116047355663278,
#    'CS_recall': 0.54347826,
#    'CS_precision': 0.71428571,
#    'CS_f1': 0.61728395,
#    'CS_threshold': 0.3746,
#    'CS_mcc': 0.533374535294191,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9534305709987573,
#    'CCPP_ap': 0.325485052408234,
#    'CCPP_recall': 0.11010363,
#    'CCPP_precision': 0.77272727,
#    'CCPP_f1': 0.19274376,
#    'CCPP_threshold': 0.298,
#    'CCPP_mcc': 0.28079175748165525,
#    'lan': 'CCPP',
#    'phase': 'mc_focal'},
#   {'JavaScript_accuracy': 0.9199288256227758,
#    'JavaScript_ap': 0.5093259175082366,
#    'JavaScript_recall': 0.2823219,
#    'JavaScript_precision': 0.71333333,
#    'JavaScript_f1': 0.40453686,
#    'JavaScript_threshold': 0.3451,
#    'JavaScript_mcc': 0.4163377245792815,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal'}],
#  [{'Python_accuracy': 0.9358108108108109,
#    'Python_ap': 0.3822932675789785,
#    'Python_recall': 0.10784314,
#    'Python_precision': 0.73333333,
#    'Python_f1': 0.18803419,
#    'Python_threshold': 0.3993,
#    'Python_mcc': 0.2654012009765638,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.8954545454545455,
#    'TypeScript_ap': 0.22913110894768002,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.0501,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.9333800841514727,
#    'Java_ap': 0.12438036144663377,
#    'Java_recall': 0.0,
#    'Java_precision': 0.0,
#    'Java_f1': 0.0,
#    'Java_threshold': 0.092,
#    'Java_mcc': 0.0,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.7822222222222223,
#    'CS_ap': 0.26374057465621414,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0203,
#    'CS_mcc': 0.0,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.9502490823282643,
#    'CCPP_ap': 0.1307462580150874,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.052,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.8990733784122213,
#    'JavaScript_ap': 0.21532662398476268,
#    'JavaScript_recall': 0.0,
#    'JavaScript_precision': 0.0,
#    'JavaScript_f1': 0.0,
#    'JavaScript_threshold': 0.0763,
#    'JavaScript_mcc': -0.007479596268124176,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.983402489626556,
#    'Python_ap': 0.8708838738271443,
#    'Python_recall': 0.76595745,
#    'Python_precision': 0.97297297,
#    'Python_f1': 0.85714286,
#    'Python_threshold': 0.0547,
#    'Python_mcc': 0.8553117495738444,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.9098360655737705,
#    'TypeScript_ap': 0.2493304927348995,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.171,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.9349930843706777,
#    'Java_ap': 0.45715981275838086,
#    'Java_recall': 0.21186441,
#    'Java_precision': 0.96153846,
#    'Java_f1': 0.34722222,
#    'Java_threshold': 0.2021,
#    'Java_mcc': 0.4349315073070547,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.8762376237623762,
#    'CS_ap': 0.7953478909185447,
#    'CS_recall': 0.5,
#    'CS_precision': 0.88,
#    'CS_f1': 0.63768116,
#    'CS_threshold': 0.202,
#    'CS_mcc': 0.6029131406487908,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.9535201196125593,
#    'CCPP_ap': 0.3533446059874038,
#    'CCPP_recall': 0.11698113,
#    'CCPP_precision': 0.87735849,
#    'CCPP_f1': 0.20643729,
#    'CCPP_threshold': 0.0772,
#    'CCPP_mcc': 0.31067352029365713,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.9195668986852281,
#    'JavaScript_ap': 0.46878082318036546,
#    'JavaScript_recall': 0.21369863,
#    'JavaScript_precision': 0.75728155,
#    'JavaScript_f1': 0.33333333,
#    'JavaScript_threshold': 0.0794,
#    'JavaScript_mcc': 0.3751542515954021,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9431345353675451,
#    'Python_ap': 0.39843616581904423,
#    'Python_recall': 0.18390805,
#    'Python_precision': 0.59259259,
#    'Python_f1': 0.28070175,
#    'Python_threshold': 0.2241,
#    'Python_mcc': 0.3087900167635984,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.9402390438247012,
#    'TypeScript_ap': 0.17776627350638327,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.2494,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.923021582733813,
#    'Java_ap': 0.14997695369408764,
#    'Java_recall': 0.04081633,
#    'Java_precision': 0.23529412,
#    'Java_f1': 0.06956522,
#    'Java_threshold': 0.1112,
#    'Java_mcc': 0.07162950058801673,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.759656652360515,
#    'CS_ap': 0.35158951308969366,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0338,
#    'CS_mcc': 0.0,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.9465857953433771,
#    'CCPP_ap': 0.1316908894631555,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.0655,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.9063291139240506,
#    'JavaScript_ap': 0.23979768216680197,
#    'JavaScript_recall': 0.01347709,
#    'JavaScript_precision': 0.55555556,
#    'JavaScript_f1': 0.02631579,
#    'JavaScript_threshold': 0.151,
#    'JavaScript_mcc': 0.0756210615040409,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.9821182943603851,
#    'Python_ap': 0.8693457697473561,
#    'Python_recall': 0.75257732,
#    'Python_precision': 0.97333333,
#    'Python_f1': 0.84883721,
#    'Python_threshold': 0.981,
#    'Python_mcc': 0.8473499349787416,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.905829596412556,
#    'TypeScript_ap': 0.21607616851373643,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.1375,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.9383611312545322,
#    'Java_ap': 0.3878524816456034,
#    'Java_recall': 0.15841584,
#    'Java_precision': 1.0,
#    'Java_f1': 0.27350427,
#    'Java_threshold': 0.2039,
#    'Java_mcc': 0.385404519736249,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8918918918918919,
#    'CS_ap': 0.6234093642204636,
#    'CS_recall': 0.36,
#    'CS_precision': 0.69230769,
#    'CS_f1': 0.47368421,
#    'CS_threshold': 0.3139,
#    'CS_mcc': 0.44806281504427753,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9533139346912383,
#    'CCPP_ap': 0.3513656806190249,
#    'CCPP_recall': 0.10566038,
#    'CCPP_precision': 0.88421053,
#    'CCPP_f1': 0.18876404,
#    'CCPP_threshold': 0.2012,
#    'CCPP_mcc': 0.29649613707333633,
#    'lan': 'CCPP',
#    'phase': 'mc_focal'},
#   {'JavaScript_accuracy': 0.9131997945557268,
#    'JavaScript_ap': 0.5135160253081826,
#    'JavaScript_recall': 0.33773087,
#    'JavaScript_precision': 0.59534884,
#    'JavaScript_f1': 0.43097643,
#    'JavaScript_threshold': 0.4256,
#    'JavaScript_mcc': 0.40617618841634734,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal'}],
#  [{'Python_accuracy': 0.9903846153846154,
#    'Python_ap': 0.8731720861725547,
#    'Python_recall': 0.8030303,
#    'Python_precision': 1.0,
#    'Python_f1': 0.8907563,
#    'Python_threshold': 0.7799,
#    'Python_mcc': 0.8916242583557866,
#    'lan': 'Python',
#    'phase': 'mc_bin'},
#   {'TypeScript_accuracy': 0.9008264462809917,
#    'TypeScript_ap': 0.25851725399074776,
#    'TypeScript_recall': 0.04,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.07692308,
#    'TypeScript_threshold': 0.0659,
#    'TypeScript_mcc': 0.18978039285019263,
#    'lan': 'TypeScript',
#    'phase': 'mc_bin'},
#   {'Java_accuracy': 0.9235580264072273,
#    'Java_ap': 0.270895227792371,
#    'Java_recall': 0.09090909,
#    'Java_precision': 0.5,
#    'Java_f1': 0.15384615,
#    'Java_threshold': 0.0649,
#    'Java_mcc': 0.18925121527846367,
#    'lan': 'Java',
#    'phase': 'mc_bin'},
#   {'CS_accuracy': 0.8428571428571429,
#    'CS_ap': 0.6817722044742389,
#    'CS_recall': 0.42,
#    'CS_precision': 0.84,
#    'CS_f1': 0.56,
#    'CS_threshold': 0.165,
#    'CS_mcc': 0.519500799884929,
#    'lan': 'CS',
#    'phase': 'mc_bin'},
#   {'CCPP_accuracy': 0.9512845528455285,
#    'CCPP_ap': 0.2760830171595033,
#    'CCPP_recall': 0.10880829,
#    'CCPP_precision': 0.57931034,
#    'CCPP_f1': 0.18320611,
#    'CCPP_threshold': 0.1077,
#    'CCPP_mcc': 0.23640485495198585,
#    'lan': 'CCPP',
#    'phase': 'mc_bin'},
#   {'JavaScript_accuracy': 0.9123556002009041,
#    'JavaScript_ap': 0.4435508836839089,
#    'JavaScript_recall': 0.29230769,
#    'JavaScript_precision': 0.60962567,
#    'JavaScript_f1': 0.39514731,
#    'JavaScript_threshold': 0.1588,
#    'JavaScript_mcc': 0.38213633332434,
#    'lan': 'JavaScript',
#    'phase': 'mc_bin'}],
#  [{'Python_accuracy': 0.9902777777777778,
#    'Python_ap': 0.8974102784114748,
#    'Python_recall': 0.83908046,
#    'Python_precision': 1.0,
#    'Python_f1': 0.9125,
#    'Python_threshold': 0.9477,
#    'Python_mcc': 0.9113106481018387,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.9227642276422764,
#    'TypeScript_ap': 0.39902862900385777,
#    'TypeScript_recall': 0.20833333,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.34482759,
#    'TypeScript_threshold': 0.1116,
#    'TypeScript_mcc': 0.43807386784987085,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.9507969507969508,
#    'Java_ap': 0.38553098558265436,
#    'Java_recall': 0.16470588,
#    'Java_precision': 1.0,
#    'Java_f1': 0.28282828,
#    'Java_threshold': 0.0307,
#    'Java_mcc': 0.3956291887970318,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.8939393939393939,
#    'CS_ap': 0.6898468882458434,
#    'CS_recall': 0.38235294,
#    'CS_precision': 1.0,
#    'CS_f1': 0.55319149,
#    'CS_threshold': 0.0675,
#    'CS_mcc': 0.5821947401182045,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.954465621544266,
#    'CCPP_ap': 0.32534082724650126,
#    'CCPP_recall': 0.11384217,
#    'CCPP_precision': 0.85436893,
#    'CCPP_f1': 0.20091324,
#    'CCPP_threshold': 0.0447,
#    'CCPP_mcc': 0.3021997006032245,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.908974358974359,
#    'JavaScript_ap': 0.4192046755765499,
#    'JavaScript_recall': 0.19060052,
#    'JavaScript_precision': 0.61864407,
#    'JavaScript_f1': 0.29141717,
#    'JavaScript_threshold': 0.0725,
#    'JavaScript_mcc': 0.30890793237572217,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9895833333333334,
#    'Python_ap': 0.8877141462816138,
#    'Python_recall': 0.82758621,
#    'Python_precision': 1.0,
#    'Python_f1': 0.90566038,
#    'Python_threshold': 0.333,
#    'Python_mcc': 0.9047164178532477,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.9227642276422764,
#    'TypeScript_ap': 0.44342836837670485,
#    'TypeScript_recall': 0.20833333,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.34482759,
#    'TypeScript_threshold': 0.2173,
#    'TypeScript_mcc': 0.43807386784987085,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.93000693000693,
#    'Java_ap': 0.3827864066667145,
#    'Java_recall': 0.30588235,
#    'Java_precision': 0.38235294,
#    'Java_f1': 0.33986928,
#    'Java_threshold': 0.4851,
#    'Java_mcc': 0.3055022425463799,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8282828282828283,
#    'CS_ap': 0.6387400636437073,
#    'CS_recall': 0.44117647,
#    'CS_precision': 0.5,
#    'CS_f1': 0.46875,
#    'CS_threshold': 0.3941,
#    'CS_mcc': 0.36783915866707756,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9556365055616991,
#    'CCPP_ap': 0.37350366723112666,
#    'CCPP_recall': 0.13195343,
#    'CCPP_precision': 0.90265487,
#    'CCPP_f1': 0.23024831,
#    'CCPP_threshold': 0.3181,
#    'CCPP_mcc': 0.3356475898758633,
#    'lan': 'CCPP',
#    'phase': 'mc_focal'},
#   {'JavaScript_accuracy': 0.9115384615384615,
#    'JavaScript_ap': 0.5288214549331002,
#    'JavaScript_recall': 0.35509138,
#    'JavaScript_precision': 0.58119658,
#    'JavaScript_f1': 0.44084279,
#    'JavaScript_threshold': 0.4577,
#    'JavaScript_mcc': 0.41004373412022616,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal'}],
#  [{'Python_accuracy': 0.9916782246879334,
#    'Python_ap': 0.9396439003183771,
#    'Python_recall': 0.89655172,
#    'Python_precision': 0.96296296,
#    'Python_f1': 0.92857143,
#    'Python_threshold': 0.9998,
#    'Python_mcc': 0.9248243188397931,
#    'lan': 'Python',
#    'phase': 'mc'},
#   {'TypeScript_accuracy': 0.9282868525896414,
#    'TypeScript_ap': 0.3213885652592684,
#    'TypeScript_recall': 0.2,
#    'TypeScript_precision': 0.33333333,
#    'TypeScript_f1': 0.25,
#    'TypeScript_threshold': 0.2131,
#    'TypeScript_mcc': 0.22256553145353372,
#    'lan': 'TypeScript',
#    'phase': 'mc'},
#   {'Java_accuracy': 0.9309352517985612,
#    'Java_ap': 0.4274395835825186,
#    'Java_recall': 0.28571429,
#    'Java_precision': 0.51851852,
#    'Java_f1': 0.36842105,
#    'Java_threshold': 0.1252,
#    'Java_mcc': 0.3518492544263383,
#    'lan': 'Java',
#    'phase': 'mc'},
#   {'CS_accuracy': 0.8755364806866953,
#    'CS_ap': 0.8069057344702935,
#    'CS_recall': 0.58928571,
#    'CS_precision': 0.84615385,
#    'CS_f1': 0.69473684,
#    'CS_threshold': 0.0089,
#    'CS_mcc': 0.6356872606650528,
#    'lan': 'CS',
#    'phase': 'mc'},
#   {'CCPP_accuracy': 0.9513467684080089,
#    'CCPP_ap': 0.3341565460204661,
#    'CCPP_recall': 0.14407814,
#    'CCPP_precision': 0.72392638,
#    'CCPP_f1': 0.24032587,
#    'CCPP_threshold': 0.0208,
#    'CCPP_mcc': 0.3091002140189918,
#    'lan': 'CCPP',
#    'phase': 'mc'},
#   {'JavaScript_accuracy': 0.9227848101265823,
#    'JavaScript_ap': 0.5432638325635418,
#    'JavaScript_recall': 0.30458221,
#    'JavaScript_precision': 0.70625,
#    'JavaScript_f1': 0.42561205,
#    'JavaScript_threshold': 0.1172,
#    'JavaScript_mcc': 0.43127307213831184,
#    'lan': 'JavaScript',
#    'phase': 'mc'}],
#  [{'Python_accuracy': 0.9831081081081081,
#    'Python_ap': 0.8599630072620958,
#    'Python_recall': 0.76470588,
#    'Python_precision': 0.98734177,
#    'Python_f1': 0.86187845,
#    'Python_threshold': 0.9565,
#    'Python_mcc': 0.860942566300904,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.8818181818181818,
#    'TypeScript_ap': 0.2643602941395459,
#    'TypeScript_recall': 0.13043478,
#    'TypeScript_precision': 0.33333333,
#    'TypeScript_f1': 0.1875,
#    'TypeScript_threshold': 0.2568,
#    'TypeScript_mcc': 0.15443249522142374,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.9474053295932678,
#    'Java_ap': 0.48460526807561255,
#    'Java_recall': 0.27368421,
#    'Java_precision': 0.8125,
#    'Java_f1': 0.40944882,
#    'Java_threshold': 0.2532,
#    'Java_mcc': 0.4531910334087852,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8666666666666667,
#    'CS_ap': 0.7903657990212778,
#    'CS_recall': 0.53061224,
#    'CS_precision': 0.78787879,
#    'CS_f1': 0.63414634,
#    'CS_threshold': 0.2852,
#    'CS_mcc': 0.5726461038961039,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9556895647614053,
#    'CCPP_ap': 0.3617825466327334,
#    'CCPP_recall': 0.171278,
#    'CCPP_precision': 0.73446328,
#    'CCPP_f1': 0.27777778,
#    'CCPP_threshold': 0.3673,
#    'CCPP_mcc': 0.34118446800444074,
#    'lan': 'CCPP',
#    'phase': 'mc_focal'},
#   {'JavaScript_accuracy': 0.9213623841723015,
#    'JavaScript_ap': 0.5881805126003873,
#    'JavaScript_recall': 0.30174564,
#    'JavaScript_precision': 0.78064516,
#    'JavaScript_f1': 0.4352518,
#    'JavaScript_threshold': 0.2678,
#    'JavaScript_mcc': 0.45480093418626066,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal'}],
#  [{'Python_accuracy': 0.9831763122476447,
#    'Python_ap': 0.8855583655301892,
#    'Python_recall': 0.77227723,
#    'Python_precision': 0.975,
#    'Python_f1': 0.86187845,
#    'Python_threshold': 0.9276,
#    'Python_mcc': 0.8596235851260279,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.932,
#    'TypeScript_ap': 0.3559189676776515,
#    'TypeScript_recall': 0.15789474,
#    'TypeScript_precision': 0.75,
#    'TypeScript_f1': 0.26086957,
#    'TypeScript_threshold': 0.3961,
#    'TypeScript_mcc': 0.3243243503994456,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9428571428571428,
#    'Java_ap': 0.44448355335260537,
#    'Java_recall': 0.29069767,
#    'Java_precision': 0.54347826,
#    'Java_f1': 0.37878788,
#    'Java_threshold': 0.4619,
#    'Java_mcc': 0.37073538341894,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8592233009708737,
#    'CS_ap': 0.7541614091553503,
#    'CS_recall': 0.5,
#    'CS_precision': 0.79310345,
#    'CS_f1': 0.61333333,
#    'CS_threshold': 0.3166,
#    'CS_mcc': 0.5538153796808907,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9546078880240696,
#    'CCPP_ap': 0.35313796032906297,
#    'CCPP_recall': 0.11398964,
#    'CCPP_precision': 0.89795918,
#    'CCPP_f1': 0.20229885,
#    'CCPP_threshold': 0.3817,
#    'CCPP_mcc': 0.31086641580340013,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9128113879003559,
#    'JavaScript_ap': 0.5341208334075387,
#    'JavaScript_recall': 0.41688654,
#    'JavaScript_precision': 0.56428571,
#    'JavaScript_f1': 0.47951442,
#    'JavaScript_threshold': 0.4451,
#    'JavaScript_mcc': 0.4390212423258136,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.9895977808599168,
#    'Python_ap': 0.8954528441567621,
#    'Python_recall': 0.89655172,
#    'Python_precision': 0.92857143,
#    'Python_f1': 0.9122807,
#    'Python_threshold': 0.9984,
#    'Python_mcc': 0.9069112996515273,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.9442231075697212,
#    'TypeScript_ap': 0.35185792003697597,
#    'TypeScript_recall': 0.06666667,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.125,
#    'TypeScript_threshold': 0.0748,
#    'TypeScript_mcc': 0.2508651696296904,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.939568345323741,
#    'Java_ap': 0.39511069889789985,
#    'Java_recall': 0.21428571,
#    'Java_precision': 0.75,
#    'Java_f1': 0.33333333,
#    'Java_threshold': 0.0811,
#    'Java_mcc': 0.38058189958461947,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.8669527896995708,
#    'CS_ap': 0.7698181847253776,
#    'CS_recall': 0.55357143,
#    'CS_precision': 0.83783784,
#    'CS_f1': 0.66666667,
#    'CS_threshold': 0.427,
#    'CS_mcc': 0.6075499724179849,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.9517380812626361,
#    'CCPP_ap': 0.3354352785913742,
#    'CCPP_recall': 0.12820513,
#    'CCPP_precision': 0.80152672,
#    'CCPP_f1': 0.22105263,
#    'CCPP_threshold': 0.0506,
#    'CCPP_mcc': 0.3088473134693392,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.9210126582278481,
#    'JavaScript_ap': 0.5377977970063009,
#    'JavaScript_recall': 0.29380054,
#    'JavaScript_precision': 0.68553459,
#    'JavaScript_f1': 0.41132075,
#    'JavaScript_threshold': 0.1475,
#    'JavaScript_mcc': 0.415323843740042,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9896449704142012,
#    'Python_ap': 0.8640342134189081,
#    'Python_recall': 0.8030303,
#    'Python_precision': 0.98148148,
#    'Python_f1': 0.88333333,
#    'Python_threshold': 0.9447,
#    'Python_mcc': 0.8828144075970721,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.8966942148760331,
#    'TypeScript_ap': 0.2766114855603736,
#    'TypeScript_recall': 0.04,
#    'TypeScript_precision': 0.5,
#    'TypeScript_f1': 0.07407407,
#    'TypeScript_threshold': 0.0955,
#    'TypeScript_mcc': 0.11898185587580053,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9270326615705351,
#    'Java_ap': 0.4306667961483586,
#    'Java_recall': 0.24545455,
#    'Java_precision': 0.55102041,
#    'Java_f1': 0.33962264,
#    'Java_threshold': 0.4061,
#    'Java_mcc': 0.33535176793036225,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8952380952380953,
#    'CS_ap': 0.8329636272866786,
#    'CS_recall': 0.66,
#    'CS_precision': 0.86842105,
#    'CS_f1': 0.75,
#    'CS_threshold': 0.6785,
#    'CS_mcc': 0.6956118468609258,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9540813008130081,
#    'CCPP_ap': 0.35259012373687604,
#    'CCPP_recall': 0.1761658,
#    'CCPP_precision': 0.66019417,
#    'CCPP_f1': 0.27811861,
#    'CCPP_threshold': 0.2627,
#    'CCPP_mcc': 0.3255053643104681,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9249121044701155,
#    'JavaScript_ap': 0.5795308501032227,
#    'JavaScript_recall': 0.36666667,
#    'JavaScript_precision': 0.73333333,
#    'JavaScript_f1': 0.48888889,
#    'JavaScript_threshold': 0.33,
#    'JavaScript_mcc': 0.48507913437881967,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.9838492597577388,
#    'Python_ap': 0.8746448906026637,
#    'Python_recall': 0.76237624,
#    'Python_precision': 1.0,
#    'Python_f1': 0.86516854,
#    'Python_threshold': 0.9982,
#    'Python_mcc': 0.8656733858719662,
#    'lan': 'Python',
#    'phase': 'mc'},
#   {'TypeScript_accuracy': 0.936,
#    'TypeScript_ap': 0.336738200102987,
#    'TypeScript_recall': 0.15789474,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.27272727,
#    'TypeScript_threshold': 0.1782,
#    'TypeScript_mcc': 0.3842743000701953,
#    'lan': 'TypeScript',
#    'phase': 'mc'},
#   {'Java_accuracy': 0.9449477351916377,
#    'Java_ap': 0.38397557513389935,
#    'Java_recall': 0.1744186,
#    'Java_precision': 0.65217391,
#    'Java_f1': 0.27522936,
#    'Java_threshold': 0.0864,
#    'Java_mcc': 0.31845175463120995,
#    'lan': 'Java',
#    'phase': 'mc'},
#   {'CS_accuracy': 0.8495145631067961,
#    'CS_ap': 0.7627163558163685,
#    'CS_recall': 0.56521739,
#    'CS_precision': 0.7027027,
#    'CS_f1': 0.62650602,
#    'CS_threshold': 0.0813,
#    'CS_mcc': 0.5386236536217642,
#    'lan': 'CS',
#    'phase': 'mc'},
#   {'CCPP_accuracy': 0.9543462620184446,
#    'CCPP_ap': 0.32330918455535507,
#    'CCPP_recall': 0.11010363,
#    'CCPP_precision': 0.88541667,
#    'CCPP_f1': 0.19585253,
#    'CCPP_threshold': 0.073,
#    'CCPP_mcc': 0.3031043612588187,
#    'lan': 'CCPP',
#    'phase': 'mc'},
#   {'JavaScript_accuracy': 0.9224707676664972,
#    'JavaScript_ap': 0.5425932198270104,
#    'JavaScript_recall': 0.34828496,
#    'JavaScript_precision': 0.69473684,
#    'JavaScript_f1': 0.46397188,
#    'JavaScript_threshold': 0.0943,
#    'JavaScript_mcc': 0.45687080780630424,
#    'lan': 'JavaScript',
#    'phase': 'mc'}],
#  [{'Python_accuracy': 0.9876965140123035,
#    'Python_ap': 0.8907471632609221,
#    'Python_recall': 0.83783784,
#    'Python_precision': 1.0,
#    'Python_f1': 0.91176471,
#    'Python_threshold': 0.6149,
#    'Python_mcc': 0.9093017922876246,
#    'lan': 'Python',
#    'phase': 'mc'},
#   {'TypeScript_accuracy': 0.9491525423728814,
#    'TypeScript_ap': 0.1298245654431826,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.0314,
#    'TypeScript_mcc': -0.014423516390225431,
#    'lan': 'TypeScript',
#    'phase': 'mc'},
#   {'Java_accuracy': 0.9378057302585604,
#    'Java_ap': 0.38759138931406445,
#    'Java_recall': 0.18,
#    'Java_precision': 0.72,
#    'Java_f1': 0.288,
#    'Java_threshold': 0.0253,
#    'Java_mcc': 0.34003269203234826,
#    'lan': 'Java',
#    'phase': 'mc'},
#   {'CS_accuracy': 0.868421052631579,
#    'CS_ap': 0.8198544163717548,
#    'CS_recall': 0.5,
#    'CS_precision': 1.0,
#    'CS_f1': 0.66666667,
#    'CS_threshold': 0.036,
#    'CS_mcc': 0.6513389472789296,
#    'lan': 'CS',
#    'phase': 'mc'},
#   {'CCPP_accuracy': 0.9551549075761521,
#    'CCPP_ap': 0.3229845632230419,
#    'CCPP_recall': 0.10814419,
#    'CCPP_precision': 0.79411765,
#    'CCPP_f1': 0.19036428,
#    'CCPP_threshold': 0.0324,
#    'CCPP_mcc': 0.28296237341715447,
#    'lan': 'CCPP',
#    'phase': 'mc'},
#   {'JavaScript_accuracy': 0.921330925973691,
#    'JavaScript_ap': 0.5433678421307687,
#    'JavaScript_recall': 0.34688347,
#    'JavaScript_precision': 0.66666667,
#    'JavaScript_f1': 0.45632799,
#    'JavaScript_threshold': 0.078,
#    'JavaScript_mcc': 0.44452205856534477,
#    'lan': 'JavaScript',
#    'phase': 'mc'}],
#  [{'Python_accuracy': 0.9807427785419532,
#    'Python_ap': 0.8430886935390632,
#    'Python_recall': 0.75257732,
#    'Python_precision': 0.94805195,
#    'Python_f1': 0.83908046,
#    'Python_threshold': 0.9892,
#    'Python_mcc': 0.8352379307683125,
#    'lan': 'Python',
#    'phase': 'mc_bin'},
#   {'TypeScript_accuracy': 0.8699551569506726,
#    'TypeScript_ap': 0.2261252814290775,
#    'TypeScript_recall': 0.0952381,
#    'TypeScript_precision': 0.16666667,
#    'TypeScript_f1': 0.12121212,
#    'TypeScript_threshold': 0.0113,
#    'TypeScript_mcc': 0.05919493488479696,
#    'lan': 'TypeScript',
#    'phase': 'mc_bin'},
#   {'Java_accuracy': 0.9108049311094997,
#    'Java_ap': 0.3655743421191568,
#    'Java_recall': 0.31683168,
#    'Java_precision': 0.37209302,
#    'Java_f1': 0.34224599,
#    'Java_threshold': 0.0523,
#    'Java_mcc': 0.2958309576337386,
#    'lan': 'Java',
#    'phase': 'mc_bin'},
#   {'CS_accuracy': 0.8918918918918919,
#    'CS_ap': 0.6609954471016616,
#    'CS_recall': 0.56,
#    'CS_precision': 0.60869565,
#    'CS_f1': 0.58333333,
#    'CS_threshold': 0.0211,
#    'CS_mcc': 0.5219436635011756,
#    'lan': 'CS',
#    'phase': 'mc_bin'},
#   {'CCPP_accuracy': 0.9432266408018105,
#    'CCPP_ap': 0.32691605390065376,
#    'CCPP_recall': 0.23522013,
#    'CCPP_precision': 0.40919037,
#    'CCPP_f1': 0.29872204,
#    'CCPP_threshold': 0.0369,
#    'CCPP_mcc': 0.2827280330968746,
#    'lan': 'CCPP',
#    'phase': 'mc_bin'},
#   {'JavaScript_accuracy': 0.899075500770416,
#    'JavaScript_ap': 0.5512704895901959,
#    'JavaScript_recall': 0.46701847,
#    'JavaScript_precision': 0.48097826,
#    'JavaScript_f1': 0.47389558,
#    'JavaScript_threshold': 0.03,
#    'JavaScript_mcc': 0.4181485013779103,
#    'lan': 'JavaScript',
#    'phase': 'mc_bin'}],
#  [{'Python_accuracy': 0.9875,
#    'Python_ap': 0.8939695019521036,
#    'Python_recall': 0.83908046,
#    'Python_precision': 0.94805195,
#    'Python_f1': 0.8902439,
#    'Python_threshold': 0.6702,
#    'Python_mcc': 0.8854946838957056,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.9227642276422764,
#    'TypeScript_ap': 0.4633738530541964,
#    'TypeScript_recall': 0.20833333,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.34482759,
#    'TypeScript_threshold': 0.187,
#    'TypeScript_mcc': 0.43807386784987085,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9216909216909217,
#    'Java_ap': 0.3452705907174274,
#    'Java_recall': 0.22352941,
#    'Java_precision': 0.28787879,
#    'Java_f1': 0.25165563,
#    'Java_threshold': 0.2889,
#    'Java_mcc': 0.21291077355620752,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8787878787878788,
#    'CS_ap': 0.6386565704547731,
#    'CS_recall': 0.5,
#    'CS_precision': 0.70833333,
#    'CS_f1': 0.5862069,
#    'CS_threshold': 0.2098,
#    'CS_mcc': 0.5284434909511891,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9534898848630716,
#    'CCPP_ap': 0.35140461361767583,
#    'CCPP_recall': 0.14747736,
#    'CCPP_precision': 0.67058824,
#    'CCPP_f1': 0.24178155,
#    'CCPP_threshold': 0.2606,
#    'CCPP_mcc': 0.30016340085913135,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9158974358974359,
#    'JavaScript_ap': 0.5055445049678413,
#    'JavaScript_recall': 0.26109661,
#    'JavaScript_precision': 0.68965517,
#    'JavaScript_f1': 0.37878788,
#    'JavaScript_threshold': 0.1025,
#    'JavaScript_mcc': 0.39054954387038826,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.9904622157006603,
#    'Python_ap': 0.9095381029264484,
#    'Python_recall': 0.85542169,
#    'Python_precision': 0.98611111,
#    'Python_f1': 0.91612903,
#    'Python_threshold': 0.9995,
#    'Python_mcc': 0.9136883742347179,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.9162995594713657,
#    'TypeScript_ap': 0.251024088363221,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.1462,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.9414600550964187,
#    'Java_ap': 0.4479587108208285,
#    'Java_recall': 0.22330097,
#    'Java_precision': 0.82142857,
#    'Java_f1': 0.35114504,
#    'Java_threshold': 0.4234,
#    'Java_mcc': 0.4099322423705224,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8908296943231441,
#    'CS_ap': 0.5722967955050362,
#    'CS_recall': 0.28571429,
#    'CS_precision': 1.0,
#    'CS_f1': 0.44444444,
#    'CS_threshold': 0.3243,
#    'CS_mcc': 0.5030889580122407,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9582684319833853,
#    'CCPP_ap': 0.3369439147715759,
#    'CCPP_recall': 0.11772853,
#    'CCPP_precision': 0.93406593,
#    'CCPP_f1': 0.20910209,
#    'CCPP_threshold': 0.2708,
#    'CCPP_mcc': 0.3235823217270177,
#    'lan': 'CCPP',
#    'phase': 'mc_focal'},
#   {'JavaScript_accuracy': 0.9165816326530613,
#    'JavaScript_ap': 0.5175748909775393,
#    'JavaScript_recall': 0.16753927,
#    'JavaScript_precision': 0.87671233,
#    'JavaScript_f1': 0.28131868,
#    'JavaScript_threshold': 0.3285,
#    'JavaScript_mcc': 0.36195956605959134,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal'}],
#  [{'Python_accuracy': 0.9427732942039618,
#    'Python_ap': 0.457202814709773,
#    'Python_recall': 0.10843373,
#    'Python_precision': 0.69230769,
#    'Python_f1': 0.1875,
#    'Python_threshold': 0.1961,
#    'Python_mcc': 0.25910146364287817,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.9162995594713657,
#    'TypeScript_ap': 0.35986476849177546,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.1178,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.9256198347107438,
#    'Java_ap': 0.1707278461372728,
#    'Java_recall': 0.08737864,
#    'Java_precision': 0.39130435,
#    'Java_f1': 0.14285714,
#    'Java_threshold': 0.1192,
#    'Java_mcc': 0.1583210158917565,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.8427947598253275,
#    'CS_ap': 0.22826949751112294,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0406,
#    'CS_mcc': -0.028129741014363746,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.953141225337487,
#    'CCPP_ap': 0.13321453655497928,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.0585,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.9022959183673469,
#    'JavaScript_ap': 0.21633329837425935,
#    'JavaScript_recall': 0.0,
#    'JavaScript_precision': 0.0,
#    'JavaScript_f1': 0.0,
#    'JavaScript_threshold': 0.0937,
#    'JavaScript_mcc': -0.005248861767072465,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.9883800410116199,
#    'Python_ap': 0.895991178576888,
#    'Python_recall': 0.84684685,
#    'Python_precision': 1.0,
#    'Python_f1': 0.91707317,
#    'Python_threshold': 0.5702,
#    'Python_mcc': 0.9145112642285914,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.9491525423728814,
#    'TypeScript_ap': 0.09272919446741776,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.2016,
#    'TypeScript_mcc': -0.014423516390225431,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9399021663172606,
#    'Java_ap': 0.4473695027963935,
#    'Java_recall': 0.18,
#    'Java_precision': 0.81818182,
#    'Java_f1': 0.29508197,
#    'Java_threshold': 0.3697,
#    'Java_mcc': 0.3667604971431749,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8903508771929824,
#    'CS_ap': 0.8263794327073706,
#    'CS_recall': 0.7,
#    'CS_precision': 0.85714286,
#    'CS_f1': 0.7706422,
#    'CS_threshold': 0.4213,
#    'CS_mcc': 0.7057510871173196,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9553501692267639,
#    'CCPP_ap': 0.31719632018203775,
#    'CCPP_recall': 0.11348465,
#    'CCPP_precision': 0.79439252,
#    'CCPP_f1': 0.19859813,
#    'CCPP_threshold': 0.3113,
#    'CCPP_mcc': 0.28996913529893475,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9169460923394377,
#    'JavaScript_ap': 0.5369312935985795,
#    'JavaScript_recall': 0.32249322,
#    'JavaScript_precision': 0.62303665,
#    'JavaScript_f1': 0.425,
#    'JavaScript_threshold': 0.3972,
#    'JavaScript_mcc': 0.4094591394847231,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.9442916093535075,
#    'Python_ap': 0.46333272975460343,
#    'Python_recall': 0.16494845,
#    'Python_precision': 1.0,
#    'Python_f1': 0.28318584,
#    'Python_threshold': 0.2458,
#    'Python_mcc': 0.3945341538725129,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.905829596412556,
#    'TypeScript_ap': 0.18424289139327665,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.0623,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.9195068890500363,
#    'Java_ap': 0.17641448670843685,
#    'Java_recall': 0.03960396,
#    'Java_precision': 0.22222222,
#    'Java_f1': 0.06722689,
#    'Java_threshold': 0.142,
#    'Java_mcc': 0.06576207042162252,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.8594594594594595,
#    'CS_ap': 0.23432279614648324,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0676,
#    'CS_mcc': -0.029140775257509806,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.9485935984481086,
#    'CCPP_ap': 0.1325858887730928,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.0615,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.9021571648690293,
#    'JavaScript_ap': 0.2185745012037638,
#    'JavaScript_recall': 0.0,
#    'JavaScript_precision': 0.0,
#    'JavaScript_f1': 0.0,
#    'JavaScript_threshold': 0.0901,
#    'JavaScript_mcc': -0.007443642765414069,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.9804054054054054,
#    'Python_ap': 0.8399843730067218,
#    'Python_recall': 0.75490196,
#    'Python_precision': 0.95061728,
#    'Python_f1': 0.84153005,
#    'Python_threshold': 0.9571,
#    'Python_mcc': 0.8375113636024268,
#    'lan': 'Python',
#    'phase': 'mc_bin'},
#   {'TypeScript_accuracy': 0.8909090909090909,
#    'TypeScript_ap': 0.26366335878099867,
#    'TypeScript_recall': 0.08695652,
#    'TypeScript_precision': 0.4,
#    'TypeScript_f1': 0.14285714,
#    'TypeScript_threshold': 0.0144,
#    'TypeScript_mcc': 0.14725908504065663,
#    'lan': 'TypeScript',
#    'phase': 'mc_bin'},
#   {'Java_accuracy': 0.9446002805049089,
#    'Java_ap': 0.39325829538907275,
#    'Java_recall': 0.26315789,
#    'Java_precision': 0.73529412,
#    'Java_f1': 0.3875969,
#    'Java_threshold': 0.7645,
#    'Java_mcc': 0.4190859526688238,
#    'lan': 'Java',
#    'phase': 'mc_bin'},
#   {'CS_accuracy': 0.8444444444444444,
#    'CS_ap': 0.631388794446468,
#    'CS_recall': 0.36734694,
#    'CS_precision': 0.81818182,
#    'CS_f1': 0.50704225,
#    'CS_threshold': 0.2876,
#    'CS_mcc': 0.4788892319093514,
#    'lan': 'CS',
#    'phase': 'mc_bin'},
#   {'CCPP_accuracy': 0.954116413214473,
#    'CCPP_ap': 0.31886175454508525,
#    'CCPP_recall': 0.18445323,
#    'CCPP_precision': 0.63348416,
#    'CCPP_f1': 0.28571429,
#    'CCPP_threshold': 0.0794,
#    'CCPP_mcc': 0.3254914399038471,
#    'lan': 'CCPP',
#    'phase': 'mc_bin'},
#   {'JavaScript_accuracy': 0.916854495366892,
#    'JavaScript_ap': 0.5020788774721794,
#    'JavaScript_recall': 0.30174564,
#    'JavaScript_precision': 0.69942197,
#    'JavaScript_f1': 0.42160279,
#    'JavaScript_threshold': 0.1971,
#    'JavaScript_mcc': 0.4241059954108239,
#    'lan': 'JavaScript',
#    'phase': 'mc_bin'}],
#  [{'Python_accuracy': 0.9414535666218035,
#    'Python_ap': 0.43709520518634665,
#    'Python_recall': 0.18811881,
#    'Python_precision': 0.79166667,
#    'Python_f1': 0.304,
#    'Python_threshold': 0.1991,
#    'Python_mcc': 0.36840297088295393,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.924,
#    'TypeScript_ap': 0.17373931445824137,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.118,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.9358885017421603,
#    'Java_ap': 0.17587943041259826,
#    'Java_recall': 0.04651163,
#    'Java_precision': 0.28571429,
#    'Java_f1': 0.08,
#    'Java_threshold': 0.1901,
#    'Java_mcc': 0.09441843303612882,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.7766990291262136,
#    'CS_ap': 0.388116897445167,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0481,
#    'CS_mcc': 0.0,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.9495061809143829,
#    'CCPP_ap': 0.12604803206223797,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.0604,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.9039145907473309,
#    'JavaScript_ap': 0.24379418186239282,
#    'JavaScript_recall': 0.00263852,
#    'JavaScript_precision': 1.0,
#    'JavaScript_f1': 0.00526316,
#    'JavaScript_threshold': 0.0758,
#    'JavaScript_mcc': 0.04883579076441711,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.9916782246879334,
#    'Python_ap': 0.936881860178455,
#    'Python_recall': 0.89655172,
#    'Python_precision': 0.96296296,
#    'Python_f1': 0.92857143,
#    'Python_threshold': 0.979,
#    'Python_mcc': 0.9248243188397931,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.9362549800796812,
#    'TypeScript_ap': 0.32659245844252344,
#    'TypeScript_recall': 0.13333333,
#    'TypeScript_precision': 0.4,
#    'TypeScript_f1': 0.2,
#    'TypeScript_threshold': 0.4302,
#    'TypeScript_mcc': 0.20463206567433428,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.9172661870503597,
#    'Java_ap': 0.36931270977666736,
#    'Java_recall': 0.23469388,
#    'Java_precision': 0.36507937,
#    'Java_f1': 0.28571429,
#    'Java_threshold': 0.3894,
#    'Java_mcc': 0.2507277119238878,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8583690987124464,
#    'CS_ap': 0.7850889640682608,
#    'CS_recall': 0.53571429,
#    'CS_precision': 0.81081081,
#    'CS_f1': 0.64516129,
#    'CS_threshold': 0.3429,
#    'CS_mcc': 0.5800680963602504,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9511511119806952,
#    'CCPP_ap': 0.32270316477752986,
#    'CCPP_recall': 0.12820513,
#    'CCPP_precision': 0.75,
#    'CCPP_f1': 0.2189781,
#    'CCPP_threshold': 0.315,
#    'CCPP_mcc': 0.2973777618426515,
#    'lan': 'CCPP',
#    'phase': 'mc_focal'},
#   {'JavaScript_accuracy': 0.9179746835443038,
#    'JavaScript_ap': 0.5100277325657342,
#    'JavaScript_recall': 0.29649596,
#    'JavaScript_precision': 0.63583815,
#    'JavaScript_f1': 0.40441176,
#    'JavaScript_threshold': 0.4064,
#    'JavaScript_mcc': 0.3975660597197373,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal'}],
#  [{'Python_accuracy': 0.9911958914159942,
#    'Python_ap': 0.9193986843267913,
#    'Python_recall': 0.85542169,
#    'Python_precision': 1.0,
#    'Python_f1': 0.92207792,
#    'Python_threshold': 0.9661,
#    'Python_mcc': 0.9205849193209861,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.8986784140969163,
#    'TypeScript_ap': 0.4288337338862955,
#    'TypeScript_recall': 0.26315789,
#    'TypeScript_precision': 0.35714286,
#    'TypeScript_f1': 0.3030303,
#    'TypeScript_threshold': 0.2658,
#    'TypeScript_mcc': 0.25313808418981226,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9393939393939394,
#    'Java_ap': 0.42691345355611393,
#    'Java_recall': 0.19417476,
#    'Java_precision': 0.8,
#    'Java_f1': 0.3125,
#    'Java_threshold': 0.2316,
#    'Java_mcc': 0.3758939365236151,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.9126637554585153,
#    'CS_ap': 0.6927010028672169,
#    'CS_recall': 0.54285714,
#    'CS_precision': 0.82608696,
#    'CS_f1': 0.65517241,
#    'CS_threshold': 0.5356,
#    'CS_mcc': 0.6251817847090146,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9557372793354102,
#    'CCPP_ap': 0.2974794918289068,
#    'CCPP_recall': 0.14127424,
#    'CCPP_precision': 0.62195122,
#    'CCPP_f1': 0.23024831,
#    'CCPP_threshold': 0.3934,
#    'CCPP_mcc': 0.2822513483107483,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9109693877551021,
#    'JavaScript_ap': 0.5308284902338819,
#    'JavaScript_recall': 0.38743455,
#    'JavaScript_precision': 0.56273764,
#    'JavaScript_f1': 0.45891473,
#    'JavaScript_threshold': 0.3705,
#    'JavaScript_mcc': 0.42073954814402637,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.9895977808599168,
#    'Python_ap': 0.9227197705638279,
#    'Python_recall': 0.86206897,
#    'Python_precision': 0.96153846,
#    'Python_f1': 0.90909091,
#    'Python_threshold': 0.6167,
#    'Python_mcc': 0.9051071169503984,
#    'lan': 'Python',
#    'phase': 'mc_bin'},
#   {'TypeScript_accuracy': 0.9322709163346613,
#    'TypeScript_ap': 0.17356364623586049,
#    'TypeScript_recall': 0.06666667,
#    'TypeScript_precision': 0.25,
#    'TypeScript_f1': 0.10526316,
#    'TypeScript_threshold': 0.0484,
#    'TypeScript_mcc': 0.10212998401674973,
#    'lan': 'TypeScript',
#    'phase': 'mc_bin'},
#   {'Java_accuracy': 0.9424460431654677,
#    'Java_ap': 0.3405904604912543,
#    'Java_recall': 0.19387755,
#    'Java_precision': 0.95,
#    'Java_f1': 0.3220339,
#    'Java_threshold': 0.0464,
#    'Java_mcc': 0.4151062643759628,
#    'lan': 'Java',
#    'phase': 'mc_bin'},
#   {'CS_accuracy': 0.8068669527896996,
#    'CS_ap': 0.5116230727236607,
#    'CS_recall': 0.23214286,
#    'CS_precision': 0.86666667,
#    'CS_f1': 0.36619718,
#    'CS_threshold': 0.0489,
#    'CS_mcc': 0.3844954798288677,
#    'lan': 'CS',
#    'phase': 'mc_bin'},
#   {'CCPP_accuracy': 0.9503684862714407,
#    'CCPP_ap': 0.22973125466934155,
#    'CCPP_recall': 0.09035409,
#    'CCPP_precision': 0.82222222,
#    'CCPP_f1': 0.16281628,
#    'CCPP_threshold': 0.0461,
#    'CCPP_mcc': 0.2627214661493073,
#    'lan': 'CCPP',
#    'phase': 'mc_bin'},
#   {'JavaScript_accuracy': 0.9134177215189874,
#    'JavaScript_ap': 0.4002771361771345,
#    'JavaScript_recall': 0.23719677,
#    'JavaScript_precision': 0.59863946,
#    'JavaScript_f1': 0.33976834,
#    'JavaScript_threshold': 0.0552,
#    'JavaScript_mcc': 0.34015069053990765,
#    'lan': 'JavaScript',
#    'phase': 'mc_bin'}],
#  [{'Python_accuracy': 0.9877883310719131,
#    'Python_ap': 0.9165178738146695,
#    'Python_recall': 0.82692308,
#    'Python_precision': 1.0,
#    'Python_f1': 0.90526316,
#    'Python_threshold': 0.1043,
#    'Python_mcc': 0.9034374857304305,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.9469026548672567,
#    'TypeScript_ap': 0.3409980403607828,
#    'TypeScript_recall': 0.14285714,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.25,
#    'TypeScript_threshold': 0.2282,
#    'TypeScript_mcc': 0.36770107646382144,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.9429175475687104,
#    'Java_ap': 0.45831735652884276,
#    'Java_recall': 0.16666667,
#    'Java_precision': 0.94117647,
#    'Java_f1': 0.28318584,
#    'Java_threshold': 0.2289,
#    'Java_mcc': 0.38299380700433033,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.9010989010989011,
#    'CS_ap': 0.7001226215437029,
#    'CS_recall': 0.51428571,
#    'CS_precision': 0.94736842,
#    'CS_f1': 0.66666667,
#    'CS_threshold': 0.4591,
#    'CS_mcc': 0.65409914220952,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.9537853253824216,
#    'CCPP_ap': 0.3442415310568937,
#    'CCPP_recall': 0.10941476,
#    'CCPP_precision': 0.86868687,
#    'CCPP_f1': 0.19435028,
#    'CCPP_threshold': 0.0819,
#    'CCPP_mcc': 0.2988645255079901,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.9144923792301731,
#    'JavaScript_ap': 0.5017791783501584,
#    'JavaScript_recall': 0.26541555,
#    'JavaScript_precision': 0.63461538,
#    'JavaScript_f1': 0.37429112,
#    'JavaScript_threshold': 0.2611,
#    'JavaScript_mcc': 0.373793821641726,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9876965140123035,
#    'Python_ap': 0.8889058953348431,
#    'Python_recall': 0.83783784,
#    'Python_precision': 1.0,
#    'Python_f1': 0.91176471,
#    'Python_threshold': 0.9782,
#    'Python_mcc': 0.9093017922876246,
#    'lan': 'Python',
#    'phase': 'mc_focal'},
#   {'TypeScript_accuracy': 0.923728813559322,
#    'TypeScript_ap': 0.14107709805153526,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.3947,
#    'TypeScript_mcc': -0.03865773123679811,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal'},
#   {'Java_accuracy': 0.9371069182389937,
#    'Java_ap': 0.3829569357261806,
#    'Java_recall': 0.17,
#    'Java_precision': 0.70833333,
#    'Java_f1': 0.27419355,
#    'Java_threshold': 0.2515,
#    'Java_mcc': 0.32706759635225535,
#    'lan': 'Java',
#    'phase': 'mc_focal'},
#   {'CS_accuracy': 0.8596491228070176,
#    'CS_ap': 0.8092893734705622,
#    'CS_recall': 0.48333333,
#    'CS_precision': 0.96666667,
#    'CS_f1': 0.64444444,
#    'CS_threshold': 0.1734,
#    'CS_mcc': 0.6218736139496447,
#    'lan': 'CS',
#    'phase': 'mc_focal'},
#   {'CCPP_accuracy': 0.9560661286123405,
#    'CCPP_ap': 0.328081956122476,
#    'CCPP_recall': 0.11481976,
#    'CCPP_precision': 0.87755102,
#    'CCPP_f1': 0.20306966,
#    'CCPP_threshold': 0.2974,
#    'CCPP_mcc': 0.3083645855114911,
# ...
#    'Java_threshold': 0.5373,
#    'Java_mcc': 0.3388511494427071,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8811881188118812,
#    'CS_ap': 0.7880122895027307,
#    'CS_recall': 0.56818182,
#    'CS_precision': 0.83333333,
#    'CS_f1': 0.67567568,
#    'CS_threshold': 0.333,
#    'CS_mcc': 0.6227720300259812,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9539101605668595,
#    'CCPP_ap': 0.3808296515303152,
#    'CCPP_recall': 0.15471698,
#    'CCPP_precision': 0.76875,
#    'CCPP_f1': 0.25759162,
#    'CCPP_threshold': 0.2971,
#    'CCPP_mcc': 0.33207085555462473,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9211136890951276,
#    'JavaScript_ap': 0.539132308261778,
#    'JavaScript_recall': 0.28493151,
#    'JavaScript_precision': 0.69798658,
#    'JavaScript_f1': 0.40466926,
#    'JavaScript_threshold': 0.2741,
#    'JavaScript_mcc': 0.4133987324070747,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.937584803256445,
#    'Python_ap': 0.5237771350525053,
#    'Python_recall': 0.125,
#    'Python_precision': 0.92857143,
#    'Python_f1': 0.22033898,
#    'Python_threshold': 0.1719,
#    'Python_mcc': 0.32809760554986045,
#    'lan': 'Python',
#    'phase': 'mc_freeze'},
#   {'TypeScript_accuracy': 0.9380530973451328,
#    'TypeScript_ap': 0.24179391722249668,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.2231,
#    'TypeScript_mcc': 0.0,
#    'lan': 'TypeScript',
#    'phase': 'mc_freeze'},
#   {'Java_accuracy': 0.9302325581395349,
#    'Java_ap': 0.18578985921539695,
#    'Java_recall': 0.08333333,
#    'Java_precision': 0.42105263,
#    'Java_f1': 0.13913043,
#    'Java_threshold': 0.1681,
#    'Java_mcc': 0.1639250751909884,
#    'lan': 'Java',
#    'phase': 'mc_freeze'},
#   {'CS_accuracy': 0.8021978021978022,
#    'CS_ap': 0.20512296437738028,
#    'CS_recall': 0.0,
#    'CS_precision': 0.0,
#    'CS_f1': 0.0,
#    'CS_threshold': 0.0254,
#    'CS_mcc': -0.03626904057724136,
#    'lan': 'CS',
#    'phase': 'mc_freeze'},
#   {'CCPP_accuracy': 0.9490536686543946,
#    'CCPP_ap': 0.1426526655206355,
#    'CCPP_recall': 0.0,
#    'CCPP_precision': 0.0,
#    'CCPP_f1': 0.0,
#    'CCPP_threshold': 0.062,
#    'CCPP_mcc': 0.0,
#    'lan': 'CCPP',
#    'phase': 'mc_freeze'},
#   {'JavaScript_accuracy': 0.9036424696460863,
#    'JavaScript_ap': 0.21907351781762835,
#    'JavaScript_recall': 0.0,
#    'JavaScript_precision': 0.0,
#    'JavaScript_f1': 0.0,
#    'JavaScript_threshold': 0.105,
#    'JavaScript_mcc': 0.0,
#    'lan': 'JavaScript',
#    'phase': 'mc_freeze'}],
#  [{'Python_accuracy': 0.9896449704142012,
#    'Python_ap': 0.8664669360015673,
#    'Python_recall': 0.8030303,
#    'Python_precision': 0.98148148,
#    'Python_f1': 0.88333333,
#    'Python_threshold': 0.998,
#    'Python_mcc': 0.8828144075970721,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.8677685950413223,
#    'TypeScript_ap': 0.30158961591760186,
#    'TypeScript_recall': 0.12,
#    'TypeScript_precision': 0.23076923,
#    'TypeScript_f1': 0.15789474,
#    'TypeScript_threshold': 0.0233,
#    'TypeScript_mcc': 0.09978266158154561,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.9339819318971508,
#    'Java_ap': 0.43254874594575277,
#    'Java_recall': 0.2,
#    'Java_precision': 0.75862069,
#    'Java_f1': 0.31654676,
#    'Java_threshold': 0.0546,
#    'Java_mcc': 0.36820490433520997,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.8904761904761904,
#    'CS_ap': 0.8222230562074988,
#    'CS_recall': 0.54,
#    'CS_precision': 1.0,
#    'CS_f1': 0.7012987,
#    'CS_threshold': 0.0275,
#    'CS_mcc': 0.6871180011766419,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.9537560975609756,
#    'CCPP_ap': 0.35251239867154127,
#    'CCPP_recall': 0.15284974,
#    'CCPP_precision': 0.67428571,
#    'CCPP_f1': 0.24920803,
#    'CCPP_threshold': 0.0634,
#    'CCPP_mcc': 0.30663306402259694,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.9234053239578102,
#    'JavaScript_ap': 0.5811456837339406,
#    'JavaScript_recall': 0.33076923,
#    'JavaScript_precision': 0.74566474,
#    'JavaScript_f1': 0.45825933,
#    'JavaScript_threshold': 0.055,
#    'JavaScript_mcc': 0.46441725482246526,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9821182943603851,
#    'Python_ap': 0.8755761498843316,
#    'Python_recall': 0.75257732,
#    'Python_precision': 0.97333333,
#    'Python_f1': 0.84883721,
#    'Python_threshold': 0.999,
#    'Python_mcc': 0.8473499349787416,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.9013452914798207,
#    'TypeScript_ap': 0.2639991646302431,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.0506,
#    'TypeScript_mcc': -0.02164001091151454,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.9361856417693981,
#    'Java_ap': 0.36872052103545794,
#    'Java_recall': 0.14851485,
#    'Java_precision': 0.88235294,
#    'Java_f1': 0.25423729,
#    'Java_threshold': 0.0421,
#    'Java_mcc': 0.3469623995586976,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.8918918918918919,
#    'CS_ap': 0.6490896870826326,
#    'CS_recall': 0.4,
#    'CS_precision': 0.66666667,
#    'CS_f1': 0.5,
#    'CS_threshold': 0.0988,
#    'CS_mcc': 0.4618404146752978,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.9519560297445846,
#    'CCPP_ap': 0.33867698764427523,
#    'CCPP_recall': 0.15974843,
#    'CCPP_precision': 0.62871287,
#    'CCPP_f1': 0.25476429,
#    'CCPP_threshold': 0.1075,
#    'CCPP_mcc': 0.30075541836133396,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.9191063174114021,
#    'JavaScript_ap': 0.55190188963486,
#    'JavaScript_recall': 0.38522427,
#    'JavaScript_precision': 0.64035088,
#    'JavaScript_f1': 0.48105437,
#    'JavaScript_threshold': 0.2221,
#    'JavaScript_mcc': 0.4568798640646302,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9871099050203528,
#    'Python_ap': 0.9090770364640652,
#    'Python_recall': 0.81730769,
#    'Python_precision': 1.0,
#    'Python_f1': 0.8994709,
#    'Python_threshold': 0.0927,
#    'Python_mcc': 0.8978462103650661,
#    'lan': 'Python',
#    'phase': 'mc'},
#   {'TypeScript_accuracy': 0.9469026548672567,
#    'TypeScript_ap': 0.44321168796849164,
#    'TypeScript_recall': 0.14285714,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.25,
#    'TypeScript_threshold': 0.3476,
#    'TypeScript_mcc': 0.36770107646382144,
#    'lan': 'TypeScript',
#    'phase': 'mc'},
#   {'Java_accuracy': 0.9422128259337562,
#    'Java_ap': 0.40417962671978486,
#    'Java_recall': 0.15625,
#    'Java_precision': 0.9375,
#    'Java_f1': 0.26785714,
#    'Java_threshold': 0.0879,
#    'Java_mcc': 0.3698628777065092,
#    'lan': 'Java',
#    'phase': 'mc'},
#   {'CS_accuracy': 0.8736263736263736,
#    'CS_ap': 0.7584094253642938,
#    'CS_recall': 0.62857143,
#    'CS_precision': 0.6875,
#    'CS_f1': 0.65671642,
#    'CS_threshold': 0.8287,
#    'CS_mcc': 0.5803392549135814,
#    'lan': 'CS',
#    'phase': 'mc'},
#   {'CCPP_accuracy': 0.9540445942442313,
#    'CCPP_ap': 0.3461356244100128,
#    'CCPP_recall': 0.13740458,
#    'CCPP_precision': 0.77697842,
#    'CCPP_f1': 0.23351351,
#    'CCPP_threshold': 0.1279,
#    'CCPP_mcc': 0.3148268976872174,
#    'lan': 'CCPP',
#    'phase': 'mc'},
#   {'JavaScript_accuracy': 0.9157840351330405,
#    'JavaScript_ap': 0.5104586855296955,
#    'JavaScript_recall': 0.21983914,
#    'JavaScript_precision': 0.7008547,
#    'JavaScript_f1': 0.33469388,
#    'JavaScript_threshold': 0.1315,
#    'JavaScript_mcc': 0.36165870422973223,
#    'lan': 'JavaScript',
#    'phase': 'mc'}],
#  [{'Python_accuracy': 0.9881656804733728,
#    'Python_ap': 0.839930714320055,
#    'Python_recall': 0.8030303,
#    'Python_precision': 0.94642857,
#    'Python_f1': 0.86885246,
#    'Python_threshold': 0.9913,
#    'Python_mcc': 0.8658933491156764,
#    'lan': 'Python',
#    'phase': 'mc'},
#   {'TypeScript_accuracy': 0.9008264462809917,
#    'TypeScript_ap': 0.30279673297066123,
#    'TypeScript_recall': 0.04,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.07692308,
#    'TypeScript_threshold': 0.0053,
#    'TypeScript_mcc': 0.18978039285019263,
#    'lan': 'TypeScript',
#    'phase': 'mc'},
#   {'Java_accuracy': 0.9332870048644892,
#    'Java_ap': 0.421987228059164,
#    'Java_recall': 0.22727273,
#    'Java_precision': 0.69444444,
#    'Java_f1': 0.34246575,
#    'Java_threshold': 0.0625,
#    'Java_mcc': 0.3725757524413323,
#    'lan': 'Java',
#    'phase': 'mc'},
#   {'CS_accuracy': 0.8857142857142857,
#    'CS_ap': 0.8605592386213453,
#    'CS_recall': 0.54,
#    'CS_precision': 0.96428571,
#    'CS_f1': 0.69230769,
#    'CS_threshold': 0.0293,
#    'CS_mcc': 0.6687567397216098,
#    'lan': 'CS',
#    'phase': 'mc'},
#   {'CCPP_accuracy': 0.9534308943089431,
#    'CCPP_ap': 0.3517306014852027,
#    'CCPP_recall': 0.18393782,
#    'CCPP_precision': 0.62280702,
#    'CCPP_f1': 0.284,
#    'CCPP_threshold': 0.037,
#    'CCPP_mcc': 0.32169001116876556,
#    'lan': 'CCPP',
#    'phase': 'mc'},
#   {'JavaScript_accuracy': 0.9218985434455048,
#    'JavaScript_ap': 0.5510506196770273,
#    'JavaScript_recall': 0.29230769,
#    'JavaScript_precision': 0.76510067,
#    'JavaScript_f1': 0.42300557,
#    'JavaScript_threshold': 0.0384,
#    'JavaScript_mcc': 0.44254197764065345,
#    'lan': 'JavaScript',
#    'phase': 'mc'}],
#  [{'Python_accuracy': 0.9827109266943291,
#    'Python_ap': 0.867138200896639,
#    'Python_recall': 0.74468085,
#    'Python_precision': 0.98591549,
#    'Python_f1': 0.84848485,
#    'Python_threshold': 0.0738,
#    'Python_mcc': 0.848809758037632,
#    'lan': 'Python',
#    'phase': 'mc'},
#   {'TypeScript_accuracy': 0.9016393442622951,
#    'TypeScript_ap': 0.2186143067559987,
#    'TypeScript_recall': 0.0,
#    'TypeScript_precision': 0.0,
#    'TypeScript_f1': 0.0,
#    'TypeScript_threshold': 0.0551,
#    'TypeScript_mcc': -0.02861819035160712,
#    'lan': 'TypeScript',
#    'phase': 'mc'},
#   {'Java_accuracy': 0.926002766251729,
#    'Java_ap': 0.45712532556991853,
#    'Java_recall': 0.26271186,
#    'Java_precision': 0.60784314,
#    'Java_f1': 0.36686391,
#    'Java_threshold': 0.1669,
#    'Java_mcc': 0.3675437385987703,
#    'lan': 'Java',
#    'phase': 'mc'},
#   {'CS_accuracy': 0.9108910891089109,
#    'CS_ap': 0.8291404314366172,
#    'CS_recall': 0.63636364,
#    'CS_precision': 0.93333333,
#    'CS_f1': 0.75675676,
#    'CS_threshold': 0.4757,
#    'CS_mcc': 0.7239516145288618,
#    'lan': 'CS',
#    'phase': 'mc'},
#   {'CCPP_accuracy': 0.9538451537411429,
#    'CCPP_ap': 0.37575424109851513,
#    'CCPP_recall': 0.15220126,
#    'CCPP_precision': 0.77070064,
#    'CCPP_f1': 0.25420168,
#    'CCPP_threshold': 0.1443,
#    'CCPP_mcc': 0.3298052842240353,
#    'lan': 'CCPP',
#    'phase': 'mc'},
#   {'JavaScript_accuracy': 0.9151843258571797,
#    'JavaScript_ap': 0.4585787620654977,
#    'JavaScript_recall': 0.2,
#    'JavaScript_precision': 0.66363636,
#    'JavaScript_f1': 0.30736842,
#    'JavaScript_threshold': 0.1284,
#    'JavaScript_mcc': 0.33325750085948225,
#    'lan': 'JavaScript',
#    'phase': 'mc'}],
#  [{'Python_accuracy': 0.9837177747625508,
#    'Python_ap': 0.8806259977107234,
#    'Python_recall': 0.76923077,
#    'Python_precision': 1.0,
#    'Python_f1': 0.86956522,
#    'Python_threshold': 0.4675,
#    'Python_mcc': 0.8694752428223754,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.9469026548672567,
#    'TypeScript_ap': 0.29795327994775084,
#    'TypeScript_recall': 0.14285714,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.25,
#    'TypeScript_threshold': 0.4672,
#    'TypeScript_mcc': 0.36770107646382144,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9323467230443975,
#    'Java_ap': 0.40471278413421313,
#    'Java_recall': 0.26041667,
#    'Java_precision': 0.5,
#    'Java_f1': 0.34246575,
#    'Java_threshold': 0.4038,
#    'Java_mcc': 0.328989703989704,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8241758241758241,
#    'CS_ap': 0.6988121485426912,
#    'CS_recall': 0.77142857,
#    'CS_precision': 0.52941176,
#    'CS_f1': 0.62790698,
#    'CS_threshold': 0.8514,
#    'CS_mcc': 0.5336937756075723,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.9533316048742546,
#    'CCPP_ap': 0.3272418192874901,
#    'CCPP_recall': 0.09923664,
#    'CCPP_precision': 0.86666667,
#    'CCPP_f1': 0.17808219,
#    'CCPP_threshold': 0.4047,
#    'CCPP_mcc': 0.2841687605340659,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9188840092999225,
#    'JavaScript_ap': 0.5186122355506513,
#    'JavaScript_recall': 0.31635389,
#    'JavaScript_precision': 0.66666667,
#    'JavaScript_f1': 0.42909091,
#    'JavaScript_threshold': 0.3833,
#    'JavaScript_mcc': 0.4230652646489936,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}],
#  [{'Python_accuracy': 0.9811574697173621,
#    'Python_ap': 0.8694299671744826,
#    'Python_recall': 0.77227723,
#    'Python_precision': 0.93975904,
#    'Python_f1': 0.84782609,
#    'Python_threshold': 0.9995,
#    'Python_mcc': 0.8424730090295877,
#    'lan': 'Python',
#    'phase': 'mc_adj'},
#   {'TypeScript_accuracy': 0.944,
#    'TypeScript_ap': 0.41393475508275146,
#    'TypeScript_recall': 0.26315789,
#    'TypeScript_precision': 1.0,
#    'TypeScript_f1': 0.41666667,
#    'TypeScript_threshold': 0.5092,
#    'TypeScript_mcc': 0.4981167541368988,
#    'lan': 'TypeScript',
#    'phase': 'mc_adj'},
#   {'Java_accuracy': 0.9393728222996516,
#    'Java_ap': 0.4019223313090184,
#    'Java_recall': 0.22093023,
#    'Java_precision': 0.48717949,
#    'Java_f1': 0.304,
#    'Java_threshold': 0.1366,
#    'Java_mcc': 0.30086213034859755,
#    'lan': 'Java',
#    'phase': 'mc_adj'},
#   {'CS_accuracy': 0.8640776699029126,
#    'CS_ap': 0.7030051360086431,
#    'CS_recall': 0.54347826,
#    'CS_precision': 0.78125,
#    'CS_f1': 0.64102564,
#    'CS_threshold': 0.1139,
#    'CS_mcc': 0.5745438819795142,
#    'lan': 'CS',
#    'phase': 'mc_adj'},
#   {'CCPP_accuracy': 0.9529727254889137,
#    'CCPP_ap': 0.35504555743823674,
#    'CCPP_recall': 0.17227979,
#    'CCPP_precision': 0.62441315,
#    'CCPP_f1': 0.27005076,
#    'CCPP_threshold': 0.0769,
#    'CCPP_mcc': 0.31155130810262605,
#    'lan': 'CCPP',
#    'phase': 'mc_adj'},
#   {'JavaScript_accuracy': 0.9178952719877986,
#    'JavaScript_ap': 0.561408923312332,
#    'JavaScript_recall': 0.40105541,
#    'JavaScript_precision': 0.61290323,
#    'JavaScript_f1': 0.48484848,
#    'JavaScript_threshold': 0.1713,
#    'JavaScript_mcc': 0.4541161444016081,
#    'lan': 'JavaScript',
#    'phase': 'mc_adj'}],
#  [{'Python_accuracy': 0.9817567567567568,
#    'Python_ap': 0.8443584930188698,
#    'Python_recall': 0.76470588,
#    'Python_precision': 0.96296296,
#    'Python_f1': 0.85245902,
#    'Python_threshold': 0.8852,
#    'Python_mcc': 0.8492383292794651,
#    'lan': 'Python',
#    'phase': 'mc_focal_adj'},
#   {'TypeScript_accuracy': 0.9045454545454545,
#    'TypeScript_ap': 0.30094446074028286,
#    'TypeScript_recall': 0.13043478,
#    'TypeScript_precision': 0.75,
#    'TypeScript_f1': 0.22222222,
#    'TypeScript_threshold': 0.2014,
#    'TypeScript_mcc': 0.28707437857098134,
#    'lan': 'TypeScript',
#    'phase': 'mc_focal_adj'},
#   {'Java_accuracy': 0.9347826086956522,
#    'Java_ap': 0.47040705632489616,
#    'Java_recall': 0.29473684,
#    'Java_precision': 0.51851852,
#    'Java_f1': 0.37583893,
#    'Java_threshold': 0.6744,
#    'Java_mcc': 0.35952535004574604,
#    'lan': 'Java',
#    'phase': 'mc_focal_adj'},
#   {'CS_accuracy': 0.8622222222222222,
#    'CS_ap': 0.7733820276514636,
#    'CS_recall': 0.3877551,
#    'CS_precision': 0.95,
#    'CS_f1': 0.55072464,
#    'CS_threshold': 0.1285,
#    'CS_mcc': 0.5541267510006059,
#    'lan': 'CS',
#    'phase': 'mc_focal_adj'},
#   {'CCPP_accuracy': 0.954116413214473,
#    'CCPP_ap': 0.3526190602819053,
#    'CCPP_recall': 0.18445323,
#    'CCPP_precision': 0.63348416,
#    'CCPP_f1': 0.28571429,
#    'CCPP_threshold': 0.3617,
#    'CCPP_mcc': 0.3254914399038471,
#    'lan': 'CCPP',
#    'phase': 'mc_focal_adj'},
#   {'JavaScript_accuracy': 0.9161031805659905,
#    'JavaScript_ap': 0.5179476107330523,
#    'JavaScript_recall': 0.28179551,
#    'JavaScript_precision': 0.70625,
#    'JavaScript_f1': 0.40285205,
#    'JavaScript_threshold': 0.3102,
#    'JavaScript_mcc': 0.4118093457838905,
#    'lan': 'JavaScript',
#    'phase': 'mc_focal_adj'}]]

# %%
# unique_phases = {item["phase"] for item in mc_filtered_lst if "phase" in item.keys()}
# grouped_data = {}
# averaged_data = {}
# for item in filtered_lst:
#     lan = item['lan']
#     if lan not in grouped_data:
#         grouped_data[lan] = []
#     grouped_data[lan].append(item)

# for lan, items in grouped_data.items():
#     avg_item = {'lan': lan}
#     metric_count = len(items)
#     for item in items:
#         for key, value in item.items():
#             if key != 'lan' and isinstance(value, (int, float)):
#                 prefix = f"{lan}_"
#                 if key.startswith(prefix):
#                     metric_key = key[len(prefix):]
#                     avg_item[metric_key] = avg_item.get(metric_key, 0) + value
#     for key, value in avg_item.items():
#         if key != 'lan':
#             avg_item[key] = value / metric_count
#             avg_item[key] = round(avg_item[key], 4)
#     averaged_data[lan] = avg_item

# write a short email to prof. Ali that as my wife's flight arrival time changed from 6pm to 4pm, I need to leave earlier to pick her up. After that I will work at home to keep progress.


ablation_list = []

phases = {item[0]['phase'] for item in mc_filtered_lst}

for phase in phases:
    mc_phase_list = [item for item in mc_filtered_lst if item[0]["phase"] == phase]

    grouped_data = {}
    averaged_data = {}

    mc_phase_list = [item for sublist in mc_phase_list for item in sublist]

    for item in mc_phase_list:
        lan = item['lan']
        if lan not in grouped_data:
            grouped_data[lan] = []
        grouped_data[lan].append(item)

    for lan, items in grouped_data.items():
        avg_item = {'lan': lan}
        metric_count = len(items)
        for item in items:
            for key, value in item.items():
                if key != 'lan' and key != 'phase' and isinstance(value, (int, float)):
                    prefix = f"{lan}_"
                    if key.startswith(prefix):
                        metric_key = key[len(prefix):]
                        avg_item[metric_key] = avg_item.get(metric_key, 0) + value
        for key, value in avg_item.items():
            if key != 'lan':
                avg_item[key] = value / metric_count
                avg_item[key] = round(avg_item[key], 4)
        averaged_data[lan] = avg_item
    
    averaged_data['phase'] = phase
    ablation_list.append(averaged_data)

# %%
len(ablation_list)
# Out:
# 6

# %%
ablation_list[0]
# Out:
# {'Python': {'lan': 'Python',
#   'accuracy': 0.9864,
#   'ap': 0.881,
#   'recall': 0.8105,
#   'precision': 0.9757,
#   'f1': 0.8847,
#   'threshold': 0.7639,
#   'mcc': 0.8822},
#  'TypeScript': {'lan': 'TypeScript',
#   'accuracy': 0.9197,
#   'ap': 0.315,
#   'recall': 0.0801,
#   'precision': 0.4231,
#   'f1': 0.1294,
#   'threshold': 0.1246,
#   'mcc': 0.161},
#  'Java': {'lan': 'Java',
#   'accuracy': 0.9389,
#   'ap': 0.4125,
#   'recall': 0.1962,
#   'precision': 0.783,
#   'f1': 0.3066,
#   'threshold': 0.0916,
#   'mcc': 0.366},
#  'CS': {'lan': 'CS',
#   'accuracy': 0.8753,
#   'ap': 0.7205,
#   'recall': 0.4724,
#   'precision': 0.854,
#   'f1': 0.6008,
#   'threshold': 0.2464,
#   'mcc': 0.5721},
#  'CCPP': {'lan': 'CCPP',
#   'accuracy': 0.9536,
#   'ap': 0.3295,
#   'recall': 0.1312,
#   'precision': 0.7442,
#   'f1': 0.2204,
#   'threshold': 0.0716,
#   'mcc': 0.2966},
#  'JavaScript': {'lan': 'JavaScript',
#   'accuracy': 0.9164,
#   'ap': 0.51,
#   'recall': 0.296,
#   'precision': 0.6576,
#   'f1': 0.4029,
#   'threshold': 0.1374,
#   'mcc': 0.4015},
#  'phase': 'mc_adj'}

# %%
from prettytable import PrettyTable

for result in ablation_list:
    print('***', result['phase'], '***')
    table = PrettyTable(['Language','Accuracy', 'AP','F1', 'Recall','Precision', 'mcc'])
    accuracy = []
    ap = []
    f1 = []
    recall = []
    precision = []
    mcc = []
    
    for lan in languages:
        table.add_row([lan, result[lan]['accuracy'], result[lan]['ap'], result[lan]['f1'], result[lan]['recall'],\
         result[lan]['precision'], result[lan]['mcc']])
        accuracy.append(result[lan]['accuracy'])
        ap.append(result[lan]['ap'])
        f1.append(result[lan]['f1'])
        recall.append(result[lan]['recall'])
        precision.append(result[lan]['precision'])
        mcc.append(result[lan]['mcc'])
    # add the average results
    table.add_row(['Average', sum(accuracy)/len(accuracy), sum(ap)/len(ap), sum(f1)/len(f1), sum(recall)/len(recall),\
         sum(precision)/len(precision), sum(mcc)/len(mcc)])
    print(table)
# Out:
# *** mc_freeze ***
# +------------+--------------------+---------------------+--------+----------------------+---------------------+----------------------+
# |  Language  |      Accuracy      |          AP         |   F1   |        Recall        |      Precision      |         mcc          |
# +------------+--------------------+---------------------+--------+----------------------+---------------------+----------------------+
# |   Python   |       0.9422       |        0.4249       | 0.2229 |        0.1326        |        0.7482       |        0.2988        |
# | TypeScript |       0.9182       |        0.2129       |  0.0   |         0.0          |         0.0         |         0.0          |
# |    Java    |       0.9268       |        0.1591       | 0.0625 |        0.0368        |        0.2214       |        0.0706        |
# |     CS     |       0.7932       |        0.3064       |  0.0   |         0.0          |         0.0         |       -0.0094        |
# |    CCPP    |       0.9496       |        0.1326       |  0.0   |         0.0          |         0.0         |         0.0          |
# | JavaScript |       0.9032       |        0.2196       | 0.0032 |        0.0016        |        0.1556       |        0.0104        |
# |  Average   | 0.9055333333333334 | 0.24258333333333335 | 0.0481 | 0.028499999999999998 | 0.18753333333333333 | 0.061733333333333335 |
# +------------+--------------------+---------------------+--------+----------------------+---------------------+----------------------+
# *** mc_bin ***
# +------------+--------------------+---------------------+---------------------+---------+--------------------+---------------------+
# |  Language  |      Accuracy      |          AP         |          F1         |  Recall |     Precision      |         mcc         |
# +------------+--------------------+---------------------+---------------------+---------+--------------------+---------------------+
# |   Python   |       0.9852       |        0.875        |        0.8757       |  0.8047 |       0.9618       |        0.8721       |
# | TypeScript |       0.9082       |        0.2663       |        0.1412       |  0.1032 |       0.3482       |        0.1384       |
# |    Java    |       0.9271       |        0.3626       |        0.2927       |  0.2215 |       0.5335       |        0.2981       |
# |     CS     |       0.8687       |        0.6945       |        0.6036       |  0.514  |       0.7759       |        0.5555       |
# |    CCPP    |       0.9484       |        0.2986       |        0.2519       |  0.1768 |       0.5352       |        0.2755       |
# | JavaScript |       0.9114       |        0.4912       |        0.4209       |  0.3473 |       0.5986       |        0.4022       |
# |  Average   | 0.9248333333333333 | 0.49803333333333333 | 0.43100000000000005 | 0.36125 | 0.6255333333333334 | 0.42363333333333336 |
# +------------+--------------------+---------------------+---------------------+---------+--------------------+---------------------+
# *** mc_adj ***
# +------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |  Language  |      Accuracy      |         AP         |         F1         |       Recall       |     Precision      |        mcc         |
# +------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |   Python   |       0.9864       |       0.881        |       0.8847       |       0.8105       |       0.9757       |       0.8822       |
# | TypeScript |       0.9197       |       0.315        |       0.1294       |       0.0801       |       0.4231       |       0.161        |
# |    Java    |       0.9389       |       0.4125       |       0.3066       |       0.1962       |       0.783        |       0.366        |
# |     CS     |       0.8753       |       0.7205       |       0.6008       |       0.4724       |       0.854        |       0.5721       |
# |    CCPP    |       0.9536       |       0.3295       |       0.2204       |       0.1312       |       0.7442       |       0.2966       |
# | JavaScript |       0.9164       |        0.51        |       0.4029       |       0.296        |       0.6576       |       0.4015       |
# |  Average   | 0.9317166666666666 | 0.5280833333333333 | 0.4241333333333333 | 0.3310666666666667 | 0.7395999999999999 | 0.4465666666666666 |
# +------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# *** mc ***
# +------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# |  Language  |      Accuracy      |         AP         |          F1         |       Recall       |     Precision      |        mcc         |
# +------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# |   Python   |       0.9866       |       0.8821       |        0.8848       |       0.8051       |       0.9842       |       0.8832       |
# | TypeScript |       0.9195       |        0.3         |        0.1155       |       0.0709       |       0.5333       |       0.1635       |
# |    Java    |       0.9386       |       0.4144       |        0.3197       |       0.2095       |       0.7342       |       0.3657       |
# |     CS     |       0.8726       |       0.7443       |        0.6016       |       0.4989       |       0.793        |       0.557        |
# |    CCPP    |       0.9543       |       0.3387       |        0.2219       |       0.1304       |       0.7946       |       0.3076       |
# | JavaScript |       0.9194       |       0.5315       |        0.4013       |       0.2818       |       0.7125       |       0.4139       |
# |  Average   | 0.9318333333333332 | 0.5351666666666667 | 0.42413333333333325 | 0.3327666666666667 | 0.7586333333333334 | 0.4484833333333333 |
# +------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+
# *** mc_focal ***
# +------------+--------------------+--------------------+---------------------+---------------------+-----------+--------------------+
# |  Language  |      Accuracy      |         AP         |          F1         |        Recall       | Precision |        mcc         |
# +------------+--------------------+--------------------+---------------------+---------------------+-----------+--------------------+
# |   Python   |       0.9867       |       0.8886       |        0.8867       |        0.8093       |   0.9822  |       0.8848       |
# | TypeScript |       0.9172       |       0.2899       |        0.1335       |        0.0818       |   0.4067  |       0.1605       |
# |    Java    |       0.9357       |       0.4193       |        0.3123       |        0.213        |   0.7344  |       0.3586       |
# |     CS     |       0.8582       |       0.7294       |        0.5919       |        0.531        |   0.7343  |       0.5325       |
# |    CCPP    |       0.9541       |       0.3456       |        0.226        |        0.1348       |   0.7958  |       0.3098       |
# | JavaScript |       0.9176       |       0.5226       |        0.3986       |        0.2866       |   0.6957  |       0.4072       |
# |  Average   | 0.9282499999999999 | 0.5325666666666667 | 0.42483333333333334 | 0.34275000000000005 |  0.72485  | 0.4422333333333333 |
# +------------+--------------------+--------------------+---------------------+---------------------+-----------+--------------------+
# *** mc_focal_adj ***
# +------------+--------------------+---------+--------+--------------------+-----------+---------------------+
# |  Language  |      Accuracy      |    AP   |   F1   |       Recall       | Precision |         mcc         |
# +------------+--------------------+---------+--------+--------------------+-----------+---------------------+
# |   Python   |       0.9862       |  0.8875 | 0.883  |       0.8098       |   0.9731  |        0.8804       |
# | TypeScript |       0.9206       |  0.3065 | 0.1833 |       0.1167       |   0.569   |        0.2265       |
# |    Java    |       0.929        |  0.4204 | 0.3317 |       0.2584       |   0.5693  |        0.3368       |
# |     CS     |       0.8766       |  0.7352 | 0.6475 |        0.57        |   0.7866  |        0.5948       |
# |    CCPP    |       0.954        |  0.3418 | 0.2255 |       0.1345       |   0.7695  |        0.3048       |
# | JavaScript |       0.9182       |  0.5345 | 0.4224 |       0.3136       |   0.6858  |        0.4233       |
# |  Average   | 0.9307666666666665 | 0.53765 | 0.4489 | 0.3671666666666667 |  0.72555  | 0.46110000000000007 |
# +------------+--------------------+---------+--------+--------------------+-----------+---------------------+

# %%
def test(a=1, b=2):
    return a+b

test(c=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /hpcfs/users/a1232991/Vuldetect/VulDetect/linevul/resultsCollection.ipynb Cell 17 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bp2-log-1.hpc.adelaide.edu.au/hpcfs/users/a1232991/Vuldetect/VulDetect/linevul/resultsCollection.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def test(a=1, b=2):
#       <a href='vscode-notebook-cell://ssh-remote%2Bp2-log-1.hpc.adelaide.edu.au/hpcfs/users/a1232991/Vuldetect/VulDetect/linevul/resultsCollection.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     return a+b
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bp2-log-1.hpc.adelaide.edu.au/hpcfs/users/a1232991/Vuldetect/VulDetect/linevul/resultsCollection.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> test(c=3)
#
# TypeError: test() got an unexpected keyword argument 'c'
